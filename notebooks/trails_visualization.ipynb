# %%
import matplotlib.pyplot as plt
import rasterio

with rasterio.open('SandExposure_aoi_trail2.tif') as src: #filepath
    data = src.read(1)
plt.imshow(data, cmap='viridis')  # Or customize colors
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import rasterio


with rasterio.open('SandExposure_2023.tif') as src: #filepath
    data = src.read(1)
plt.imshow(data, cmap='viridis')  # Or customize colors
plt.colorbar()
plt.show()
